# %% [markdown]
# ## Impact of alignment-based deviations w.r.t time

# %% [markdown]
# ### Importing a log (P2P Process BPIC'19)

# %%
import time
from tqdm import tqdm
import pm4py
import warnings
warnings.simplefilter('ignore')
import matplotlib.pyplot as plt
from collections import Counter

from process_atoms.mine.declare.enums.mp_constants import Template
from process_atoms.processatoms import ProcessAtoms
from process_atoms.mine.declare.regexchecker import RegexChecker
import pandas as pd
import seaborn as sns

from process_atoms.models.event_log import EventLog, EventLogSchemaTypes
from process_atoms.models.column_types import (
    CaseID,
    Categorical,
    EventType,
    EventTime,
    Continuous,
)

schema = EventLogSchemaTypes(
    # schema for case-level attributes
    cases={
        "Case ID": CaseID,
        "(case) Company": Categorical,
        "(case) Document Type": Categorical,
        "(case) GR-Based Inv. Verif.": Categorical,
        "(case) Goods Receipt": Categorical,
        "(case) Item": Categorical,
        "(case) Item Category": Categorical,
        "(case) Item Type": Categorical,
        "(case) Name": Categorical,
        "(case) Purch. Doc. Category name": Categorical,
        "(case) Purchasing Document": Categorical,
        "(case) Source": Categorical,
        "(case) Spend area text": Categorical,
        "(case) Spend classification text": Categorical,
        "(case) Sub spend area text": Categorical,
        "(case) Vendor": Categorical,
        "Cumulative net worth (EUR)": Continuous,
    },
    events={
        "Case ID": CaseID,
        "Activity": EventType,
        "Complete Timestamp": EventTime,
        "Resource": Categorical,
    },
)

LOG_PATH = "data/BPI_Challenge_2019.csv"
PROCESS = "BPIC_19"
sub_process = '3-way match, invoice after GR'
MODEL_PATH= "data/"+sub_process+".bpmn"
from data.handling import transform_to_log, transform_to_pn, generate_alignments_adjusted_tracecost_pkl
log = transform_to_log(LOG_PATH)
net, initial_marking, final_marking=transform_to_pn(MODEL_PATH)

# %%
LOG_PATH = "data/BPI_Challenge_2019-3-w-after.xes"
log = pm4py.read_xes(LOG_PATH)
# Out:
# parsing log, completed traces ::   0%|          | 0/15182 [00:00<?, ?it/s]

# %%
log
# Out:
#        lifecycle:transition            time:timestamp  \
# 0                  complete 2018-01-03 09:49:00+00:00
# 1                  complete 2018-01-03 10:49:00+00:00
# 2                  complete 2018-01-03 10:49:00+00:00
# 3                  complete 2018-01-03 10:49:00+00:00
# 4                  complete 2018-01-03 10:49:00+00:00
# ...                     ...                       ...
# 319228             complete 2018-12-31 23:34:00+00:00
# 319229             complete 2018-12-31 23:34:00+00:00
# 319230             complete 2018-12-31 23:34:00+00:00
# 319231             complete 2018-12-31 23:34:00+00:00
# 319232             complete 2018-12-31 23:34:00+00:00
#
#         Cumulative net worth (EUR)      User                concept:name  \
# 0                            557.0  batch_00                SRM: Created
# 1                            557.0  batch_00               SRM: Complete
# 2                            557.0  batch_00      SRM: Awaiting Approval
# 3                            557.0  batch_00     SRM: Document Completed
# 4                            557.0  batch_00                SRM: Ordered
# ...                            ...       ...                         ...
# 319228                        47.0      NONE  Record Service Entry Sheet
# 319229                        47.0      NONE  Record Service Entry Sheet
# 319230                        47.0      NONE  Record Service Entry Sheet
# 319231                      2577.0  batch_02        Record Goods Receipt
# 319232                      2052.0  batch_02        Record Goods Receipt
#
#        org:resource case:concept:name  case:variant  case:variant-index  \
# 0          batch_00  2000000001_00001   Variant 342                 342
# 1          batch_00  2000000001_00001   Variant 342                 342
# 2          batch_00  2000000001_00001   Variant 342                 342
# 3          batch_00  2000000001_00001   Variant 342                 342
# 4          batch_00  2000000001_00001   Variant 342                 342
# ...             ...               ...           ...                 ...
# 319228         NONE  4508075963_00001  Variant 4228                4228
# 319229         NONE  4508075963_00001  Variant 4228                4228
# 319230         NONE  4508075963_00001  Variant 4228                4228
# 319231     batch_02  4508075963_00001  Variant 4228                4228
# 319232     batch_02  4508075963_00001  Variant 4228                4228
#
#           case:creator  ...      case:(case) Item Category  \
# 0       Fluxicon Disco  ...  3-way match, invoice after GR
# 1       Fluxicon Disco  ...  3-way match, invoice after GR
# 2       Fluxicon Disco  ...  3-way match, invoice after GR
# 3       Fluxicon Disco  ...  3-way match, invoice after GR
# 4       Fluxicon Disco  ...  3-way match, invoice after GR
# ...                ...  ...                            ...
# 319228  Fluxicon Disco  ...  3-way match, invoice after GR
# 319229  Fluxicon Disco  ...  3-way match, invoice after GR
# 319230  Fluxicon Disco  ...  3-way match, invoice after GR
# 319231  Fluxicon Disco  ...  3-way match, invoice after GR
# 319232  Fluxicon Disco  ...  3-way match, invoice after GR
#
#        case:(case) Item Type  case:(case) Name  \
# 0                    Service       vendor_0001
# 1                    Service       vendor_0001
# 2                    Service       vendor_0001
# 3                    Service       vendor_0001
# 4                    Service       vendor_0001
# ...                      ...               ...
# 319228               Service       vendor_0229
# 319229               Service       vendor_0229
# 319230               Service       vendor_0229
# 319231               Service       vendor_0229
# 319232               Service       vendor_0229
#
#         case:(case) Purch. Doc. Category name  \
# 0                              Purchase order
# 1                              Purchase order
# 2                              Purchase order
# 3                              Purchase order
# 4                              Purchase order
# ...                                       ...
# 319228                         Purchase order
# 319229                         Purchase order
# 319230                         Purchase order
# 319231                         Purchase order
# 319232                         Purchase order
#
#         case:(case) Purchasing Document   case:(case) Source  \
# 0                            2000000001  sourceSystemID_0000
# 1                            2000000001  sourceSystemID_0000
# 2                            2000000001  sourceSystemID_0000
# 3                            2000000001  sourceSystemID_0000
# 4                            2000000001  sourceSystemID_0000
# ...                                 ...                  ...
# 319228                       4508075963  sourceSystemID_0000
# 319229                       4508075963  sourceSystemID_0000
# 319230                       4508075963  sourceSystemID_0000
# 319231                       4508075963  sourceSystemID_0000
# 319232                       4508075963  sourceSystemID_0000
#
#        case:(case) Spend area text case:(case) Spend classification text  \
# 0                        Marketing                                   NPR
# 1                        Marketing                                   NPR
# 2                        Marketing                                   NPR
# 3                        Marketing                                   NPR
# 4                        Marketing                                   NPR
# ...                            ...                                   ...
# 319228                   Logistics                                   NPR
# 319229                   Logistics                                   NPR
# 319230                   Logistics                                   NPR
# 319231                   Logistics                                   NPR
# 319232                   Logistics                                   NPR
#
#        case:(case) Sub spend area text  case:(case) Vendor
# 0           Marketing Support Services       vendorID_0001
# 1           Marketing Support Services       vendorID_0001
# 2           Marketing Support Services       vendorID_0001
# 3           Marketing Support Services       vendorID_0001
# 4           Marketing Support Services       vendorID_0001
# ...                                ...                 ...
# 319228                     Road Packed       vendorID_0234
# 319229                     Road Packed       vendorID_0234
# 319230                     Road Packed       vendorID_0234
# 319231                     Road Packed       vendorID_0234
# 319232                     Road Packed       vendorID_0234
#
# [319233 rows x 25 columns]

# %% [markdown]
# ### First, detect the deviations per trace and impact dimension (duration of traces in h)

# %%
aligned_traces=generate_alignments_adjusted_tracecost_pkl(log, net, initial_marking, final_marking)
dev=[] # stores all deviations that happened
dev_pairs=[] # store them as tuples
for i, trace in enumerate(log):
    no_moves=len(aligned_traces[i]['alignment'])
    for j in range(0,len(aligned_traces[i]['alignment'])):
        if aligned_traces[i]['alignment'][j][1] == None or aligned_traces[i]['alignment'][j][0]==aligned_traces[i]['alignment'][j][1]:
            next # we do not care for simultaneous or silent moves
        else:
            if not str(aligned_traces[i]['alignment'][j]) in dev:
                dev.append(str(aligned_traces[i]['alignment'][j]))
                dev_pairs.append((aligned_traces[i]['alignment'][j][0],aligned_traces[i]['alignment'][j][1]))
collect_data=pd.DataFrame(data=0, index=range(len(log)), columns=dev)
collect_data['duration']=None
collect_data['case_id']=None
for i, ali in enumerate(aligned_traces):
    collect_data['case_id'][i]=log[i].attributes['concept:name']
    collect_data['duration'][i]=(log[i][len(log[i])-1]['time:timestamp']-log[i][0]['time:timestamp']).total_seconds()/60/60
    for c in range(len(dev)):
        d = dev[c]
        dp = dev_pairs[c]
        if dp in ali['alignment']:
            collect_data[d][i]=1
collect_data['duration']=collect_data['duration'].astype(float)
# Out:
# aligning log, completed variants ::   0%|          | 0/4228 [00:00<?, ?it/s]

# %% [markdown]
# ### Quantify the impact of each deviation on duration based on Conditional Average Treatment Effect (CATE)

# %%
from dowhy import CausalModel as dowhymodel
from dowhy import gcm
import networkx as nx
import ast



cates = {}
for d in dev:

    graph = f'digraph {{ "{d}" -> "duration" }}'

    model = dowhymodel(
        data=collect_data,
        treatment=d,
        outcome='duration',
        graph=graph,
        instruments=list(collect_data.drop(columns=d).columns)
    )
    identified_estimand = model.identify_effect(proceed_when_unidentifiable=True)
    cates[d] = model.estimate_effect(
        identified_estimand,
        method_name="backdoor.linear_regression",
        test_significance=True
    ).value

# %%
cates
# Out:
# {"('Vendor creates invoice', '>>')": 1737.7307035699914,
#  "('SRM: In Transfer to Execution Syst.', '>>')": 4292.862973246378,
#  "('SRM: Transfer Failed (E.Sys.)', '>>')": 6141.6834938181155,
#  "('Record Goods Receipt', '>>')": -249.6948605445964,
#  "('Record Service Entry Sheet', '>>')": -612.6475628957239,
#  "('Cancel Goods Receipt', '>>')": 382.4724049150518,
#  "('>>', 'Record Goods Receipt')": -1415.3424355207917,
#  "('>>', 'Record Invoice Receipt')": -2227.942361084534,
#  "('>>', 'Clear Invoice')": -1738.12150072939,
#  "('Change Delivery Indicator', '>>')": 1093.9072493114727,
#  "('Record Invoice Receipt', '>>')": 3238.182249225438,
#  "('Clear Invoice', '>>')": 3918.52288358979,
#  "('SRM: Created', '>>')": 2881.8665844686057,
#  "('SRM: Complete', '>>')": 2881.8665844686057,
#  "('SRM: Awaiting Approval', '>>')": 2881.8665844686057,
#  "('SRM: Document Completed', '>>')": 2819.7902770908468,
#  "('SRM: Ordered', '>>')": 2853.0216408228343,
#  "('SRM: Deleted', '>>')": 2881.8665844686057,
#  "('Change Price', '>>')": 1988.7653806971953,
#  "('SRM: Change was Transmitted', '>>')": 1510.637175590912,
#  "('>>', 'SRM: Change was Transmitted')": -1495.1118493732906,
#  "('Vendor creates debit memo', '>>')": 4080.3326741233723,
#  "('Cancel Invoice Receipt', '>>')": 4204.039992817893,
#  "('>>', 'SRM: In Transfer to Execution Syst.')": -1509.0441993225825,
#  "('Remove Payment Block', '>>')": 3769.4782167870253,
#  "('Delete Purchase Order Item', '>>')": -1338.5606301225137,
#  "('SRM: Transaction Completed', '>>')": 215.4112333883195,
#  "('>>', 'SRM: Ordered')": -1506.3088926289115,
#  "('Change Final Invoice Indicator', '>>')": 1420.287009830897,
#  "('SRM: Incomplete', '>>')": 628.6589541192463,
#  "('SRM: Held', '>>')": 628.6589541192463,
#  "('>>', 'SRM: Created')": -1503.2222824274438,
#  "('>>', 'SRM: Complete')": -1503.2222824274438,
#  "('>>', 'SRM: Awaiting Approval')": -1503.2222824274438,
#  "('>>', 'SRM: Document Completed')": -1510.3597864605742,
#  "('Change Quantity', '>>')": 592.4523501100482,
#  "('Change Approval for Purchase Order', '>>')": 61.48014490603509,
#  "('Set Payment Block', '>>')": -2.6769847456369007,
#  "('Cancel Subsequent Invoice', '>>')": 3421.3657142856746,
#  "('Create Purchase Requisition Item', '>>')": -547.045815392459,
#  "('Receive Order Confirmation', '>>')": 264.9939217975268,
#  "('Record Subsequent Invoice', '>>')": 3218.6724365309274,
#  "('Reactivate Purchase Order Item', '>>')": 121.39498817346976,
#  "('Change Rejection Indicator', '>>')": 190.5577981248232,
#  "('Change Storage Location', '>>')": 2160.126965251343,
#  "('Release Purchase Order', '>>')": 786.5803899611838,
#  "('Change payment term', '>>')": -733.836422721308}

# %% [markdown]
# ### Then assign severity based on severity function

# %%
def severity(value):
    if value == 0:
        return "neutral"
    elif -100 <= value < 0:
        return "low negative"
    elif -1000 <= value < -100:
        return "medium negative"
    elif -10000 <= value < -1000:
        return "high negative"
    elif value < -10000:
        return "critical negative"
    elif 0 < value <= 100:
        return "low positive"
    elif 100 < value <= 1000:
        return "medium positive"
    elif 1000 < value <= 10000:
        return "high positive"
    elif value > 10000:
        return "critical positive"
    else:
        return "undefined"


severities = {}
for deviation, penalty in cates.items():
    severities[deviation] = severity(penalty)

# %%
counter = Counter(severities.values())

print(counter)
# Out:
# Counter({'high positive': 21, 'high negative': 11, 'medium positive': 9, 'medium negative': 4, 'low positive': 1, 'low negative': 1})

# %%
severities
# Out:
# {"('Vendor creates invoice', '>>')": 'high positive',
#  "('SRM: In Transfer to Execution Syst.', '>>')": 'high positive',
#  "('SRM: Transfer Failed (E.Sys.)', '>>')": 'high positive',
#  "('Record Goods Receipt', '>>')": 'medium negative',
#  "('Record Service Entry Sheet', '>>')": 'medium negative',
#  "('Cancel Goods Receipt', '>>')": 'medium positive',
#  "('>>', 'Record Goods Receipt')": 'high negative',
#  "('>>', 'Record Invoice Receipt')": 'high negative',
#  "('>>', 'Clear Invoice')": 'high negative',
#  "('Change Delivery Indicator', '>>')": 'high positive',
#  "('Record Invoice Receipt', '>>')": 'high positive',
#  "('Clear Invoice', '>>')": 'high positive',
#  "('SRM: Created', '>>')": 'high positive',
#  "('SRM: Complete', '>>')": 'high positive',
#  "('SRM: Awaiting Approval', '>>')": 'high positive',
#  "('SRM: Document Completed', '>>')": 'high positive',
#  "('SRM: Ordered', '>>')": 'high positive',
#  "('SRM: Deleted', '>>')": 'high positive',
#  "('Change Price', '>>')": 'high positive',
#  "('SRM: Change was Transmitted', '>>')": 'high positive',
#  "('>>', 'SRM: Change was Transmitted')": 'high negative',
#  "('Vendor creates debit memo', '>>')": 'high positive',
#  "('Cancel Invoice Receipt', '>>')": 'high positive',
#  "('>>', 'SRM: In Transfer to Execution Syst.')": 'high negative',
#  "('Remove Payment Block', '>>')": 'high positive',
#  "('Delete Purchase Order Item', '>>')": 'high negative',
#  "('SRM: Transaction Completed', '>>')": 'medium positive',
#  "('>>', 'SRM: Ordered')": 'high negative',
#  "('Change Final Invoice Indicator', '>>')": 'high positive',
#  "('SRM: Incomplete', '>>')": 'medium positive',
#  "('SRM: Held', '>>')": 'medium positive',
#  "('>>', 'SRM: Created')": 'high negative',
#  "('>>', 'SRM: Complete')": 'high negative',
#  "('>>', 'SRM: Awaiting Approval')": 'high negative',
#  "('>>', 'SRM: Document Completed')": 'high negative',
#  "('Change Quantity', '>>')": 'medium positive',
#  "('Change Approval for Purchase Order', '>>')": 'low positive',
#  "('Set Payment Block', '>>')": 'low negative',
#  "('Cancel Subsequent Invoice', '>>')": 'high positive',
#  "('Create Purchase Requisition Item', '>>')": 'medium negative',
#  "('Receive Order Confirmation', '>>')": 'medium positive',
#  "('Record Subsequent Invoice', '>>')": 'high positive',
#  "('Reactivate Purchase Order Item', '>>')": 'medium positive',
#  "('Change Rejection Indicator', '>>')": 'medium positive',
#  "('Change Storage Location', '>>')": 'high positive',
#  "('Release Purchase Order', '>>')": 'medium positive',
#  "('Change payment term', '>>')": 'medium negative'}
